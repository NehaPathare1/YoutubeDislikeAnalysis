# %% [markdown]
# **<h3>1. Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top 5 and bottom 5 records.</h3>**

# %%
#Importing Pandas library
import pandas as pd

# %%
#Reading the DataSet
data=pd.read_csv("https://olympus.mygreatlearning.com/courses/108647/files/10013048/download?verifier=6PcAa5PTb9vYD26K5N32XcnrJDJopQYXrMXbWN2F&wrap=1")

# %%
#Retrieving top 5 records
data.head()  #
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# 2      925281   11212       401            831
# 3     2641597   39131       441           3745
# 4      715724   32887       367           1067
#
#                                                 tags  \
# 0  football soccer ftbol alemn Bundesliga season ...
# 1  Migos Avalanche Quality Control Music/Motown R...
# 2
# 3  PRODUCE101JAPAN              JO1   TheSTAR STA...
# 4  retaining wall New Jersey highway Direct Conne...
#
#                                          description  \
# 0  Enjoy the best skills and goals from Jadon San...
# 1  Watch the the official video for Migos - "Aval...
# 2  Hannah Waddingham wins the Emmy for Supporting...
# 3  JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO\n\n---...
# 4  One of the most important (and innocuous) part...
#
#                                             comments
# 0  Respect to Dortmund fans,must be sad losing hi...
# 1  Migos just makes me want to live my live to th...
# 2  Hannah's energy bursts through any screen. Wel...
# 3  youngVer><  REN is really PERFECT. It's not ju...
# 4   Keep up with all my projects here: https://pr...

# %%
#Retrieving bottom 5 records
data.tail()
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# 37418     2841917    20759      1049           2624
# 37419    13346678   720854      4426          90616
# 37420      252057    19198      1234           1471
# 37421     2252090    34063       868           2004
#
#                                                     tags  \
# 37417  Lil Tjay Steady Calling My Phone Calling My Ph...
# 37418  NBA G League Basketball game-0022000187 Lakers...
# 37419  MAMAMOO  WAW  WAW MAMAMOO WAW Where Are We Now...
# 37420  master masterpodcast lord lord vinheteiro z z ...
# 37421  Spurs Tottenham Hotspur   Tottenham Leicester ...
#
#                                              description  \
# 37417  Official video for "Calling My Phone" by Lil T...
# 37418  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  [MV]  (MAMAMOO) - Where Are We Now\n\nInstagra...
# 37420  DOCTOR HAIR\nhttps://www.thedoctorhair.com/?fb...
# 37421  Two minute highlights from Tottenham Hotspur's...
#
#                                                 comments
# 37417  'DESTINED 2 WIN' OUT NOW !! https://liltjay.ln...
# 37418  Montrezl Harrell is going crazy with the rebou...
# 37419  I honestly do not know why this song hit so ha...
# 37420  Foi um prazer passar esta tarde com vocs debat...
# 37421  Thank you Kane for everything you have given t...

# %% [markdown]
# **<h3>2. Check the info of the dataframe and write your inferences on data types and shape of the dataset.</h3>**

# %%
data.info()
print(data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB
# (37422, 12)

# %% [markdown]
# In this dataframe there are two datatypes:
#
#  object- Non-numeric values present, kind of objects inside a class- categories could be there datem time, qualitative data etc.
#
#  integer- it means there are numerical values present in 4 columns namely, view_count, likes, dislikes and comment_count.
#
# Shape of data:
#
# There are 37422 rows and 12 columns in the dataframe

# %% [markdown]
# **<h3>3. Check for the Percentage of the missing values and drop or impute them.**</h3>

# %%
(data.isnull().sum() /len(data)) * 100
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.422212
# dtype: float64

# %% [markdown]
#  Only comments column has null values and that is 0.42% which are 158 missing values

# %%
data.dropna(inplace=True)   # I have saved this new dataset after dropping missing values in original dataset with help of inplace=True

# %% [markdown]
#  With help of dropna(), I dropped all missing values from comments column because this column contains all sort of different comments which will not be of great help as of now, if it would have been in categories as positive or negative comments then we could have used it. For now I am dropping it

# %%
data.isnull().sum() # All missing values dropped
# Out:
# video_id         0
# title            0
# channel_id       0
# channel_title    0
# published_at     0
# view_count       0
# likes            0
# dislikes         0
# comment_count    0
# tags             0
# description      0
# comments         0
# dtype: int64

# %% [markdown]
# **<h3>4. Check the statistical summary of both numerical and categorical columns and write your inferences.**

# %%
numerical_summary = data.describe()
numerical_summary
# Out:
#                         published_at    view_count         likes  \
# count                          37264  3.726400e+04  3.726400e+04
# mean   2021-04-10 11:29:28.715891968  5.710821e+06  1.672867e+05
# min              2020-07-27 21:49:32  2.036800e+04  2.200000e+01
# 25%    2020-12-01 10:22:35.249999872  5.141305e+05  1.331725e+04
# 50%       2021-04-10 10:00:09.500000  1.321860e+06  4.255600e+04
# 75%              2021-08-15 20:20:59  3.674527e+06  1.309665e+05
# max              2021-12-08 05:20:47  1.322797e+09  3.183768e+07
# std                              NaN  2.431304e+07  5.384931e+05
#
#            dislikes  comment_count  publisd_month
# count  3.726400e+04   3.726400e+04   37264.000000
# mean   4.996434e+03   9.966953e+03       7.495545
# min    3.000000e+00   1.000000e+00       1.000000
# 25%    2.827500e+02   9.140000e+02       5.000000
# 50%    7.980000e+02   2.347000e+03       8.000000
# 75%    2.466250e+03   6.212000e+03      10.000000
# max    2.397733e+06   1.607103e+07      12.000000
# std    3.075194e+04   1.173465e+05       3.306261

# %% [markdown]
# Maximum views on the videos is 1,322,796,924, minimum is 20,368, average views are 5,710,821.45, median is 1,321,860.5, range is between 3,674,527.25 and 514,130.5 (i.e., 3,160,396.75), and the standard deviation is 24,313,037.51.
#
# Maximum likes on the videos is 31,837,675, minimum is 22, average likes are 167,286.70, median is 42,556, range is between 130,966.5 and 13,317.25 (i.e., 117,649.25), and the standard deviation is 538,493.10.
#
# Maximum dislikes on the videos is 2,397,733, minimum is 3, average dislikes are 4,996.43, median is 798, range is between 2,466.25 and 282.75 (i.e., 2,183.5), and the standard deviation is 30,751.94.
#
# Maximum comments on the videos is 16,071,029, minimum is 1, average comments are 9,966.95, median is 2,347, range is between 6,212 and 914 (i.e., 5,298), and the standard deviation is 117,346.47.

# %%
data.describe(include='object')
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37264  37264                     37264                37264
# unique        37264  36958                     10891                10813
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
#
#          tags description                                           comments  \
# count   37264       37264                                              37264
# unique  28705       35479                                              37264
# top                        Respect to Dortmund fans,must be sad losing hi...
# freq     3808         587                                                  1
#
#        published_month
# count            37264
# unique              12
# top            October
# freq              4976

# %% [markdown]
# There are 37,264 unique video IDs, 36,958 unique video titles, 10,891 unique channel IDs, 10,813 unique channel titles, 28,705 unique tags, 35,479 unique video descriptions, 37,264 unique video comments, and the videos were posted throughout the year, each month.
#
# The top YouTube channel is Sky Sports Football.
#
# The top YouTube video title is "www."
#
# The highest number of videos was posted in October, totaling 4,976.

# %% [markdown]
# **<h3>5. Convert datatype of column published_at from object to pandas datetime.**

# %%
#conversion of datatype usng to_datetime()
data['published_at'] = pd.to_datetime(data['published_at'])
data['published_at']
# Out:
# 0       2021-07-01 10:00:00
# 1       2021-06-10 16:00:00
# 2       2021-09-20 01:03:32
# 3       2021-03-03 10:00:17
# 4       2021-12-07 13:00:00
#                 ...
# 37417   2021-02-12 05:03:49
# 37418   2021-01-16 05:39:05
# 37419   2021-06-02 09:00:10
# 37420   2020-10-20 20:59:30
# 37421   2021-05-23 21:00:31
# Name: published_at, Length: 37264, dtype: datetime64[ns]

# %% [markdown]
# **<h3>6. Create a new column as 'published_month' using the column published_at (display the months only)**

# %%
import datetime as dt
data["publisd_month"]=data["published_at"].dt.month
data
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# 0      UC6UL29enLNe4mqwTfAyeNuw             Bundesliga 2021-07-01 10:00:00
# 1      UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO 2021-06-10 16:00:00
# 2      UClBKH8yZRcM4AsRjDVEdjMg     Television Academy 2021-09-20 01:03:32
# 3      UCsmXiDP8S40uBeJYxvyulmA                    JO1 2021-03-03 10:00:17
# 4      UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering 2021-12-07 13:00:00
# ...                         ...                    ...                 ...
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q               Lil Tjay 2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                    NBA 2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA                MAMAMOO 2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g         Master Podcast 2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w      Tottenham Hotspur 2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 0         1048888    19515       226           1319
# 1        15352638   359277      7479          18729
# 2          925281    11212       401            831
# 3         2641597    39131       441           3745
# 4          715724    32887       367           1067
# ...           ...      ...       ...            ...
# 37417   120408275  2180780     35871          81360
# 37418     2841917    20759      1049           2624
# 37419    13346678   720854      4426          90616
# 37420      252057    19198      1234           1471
# 37421     2252090    34063       868           2004
#
#                                                     tags  \
# 0      football soccer ftbol alemn Bundesliga season ...
# 1      Migos Avalanche Quality Control Music/Motown R...
# 2
# 3      PRODUCE101JAPAN              JO1   TheSTAR STA...
# 4      retaining wall New Jersey highway Direct Conne...
# ...                                                  ...
# 37417  Lil Tjay Steady Calling My Phone Calling My Ph...
# 37418  NBA G League Basketball game-0022000187 Lakers...
# 37419  MAMAMOO  WAW  WAW MAMAMOO WAW Where Are We Now...
# 37420  master masterpodcast lord lord vinheteiro z z ...
# 37421  Spurs Tottenham Hotspur   Tottenham Leicester ...
#
#                                              description  \
# 0      Enjoy the best skills and goals from Jadon San...
# 1      Watch the the official video for Migos - "Aval...
# 2      Hannah Waddingham wins the Emmy for Supporting...
# 3      JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO\n\n---...
# 4      One of the most important (and innocuous) part...
# ...                                                  ...
# 37417  Official video for "Calling My Phone" by Lil T...
# 37418  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  [MV]  (MAMAMOO) - Where Are We Now\n\nInstagra...
# 37420  DOCTOR HAIR\nhttps://www.thedoctorhair.com/?fb...
# 37421  Two minute highlights from Tottenham Hotspur's...
#
#                                                 comments  publisd_month
# 0      Respect to Dortmund fans,must be sad losing hi...              7
# 1      Migos just makes me want to live my live to th...              6
# 2      Hannah's energy bursts through any screen. Wel...              9
# 3      youngVer><  REN is really PERFECT. It's not ju...              3
# 4       Keep up with all my projects here: https://pr...             12
# ...                                                  ...            ...
# 37417  'DESTINED 2 WIN' OUT NOW !! https://liltjay.ln...              2
# 37418  Montrezl Harrell is going crazy with the rebou...              1
# 37419  I honestly do not know why this song hit so ha...              6
# 37420  Foi um prazer passar esta tarde com vocs debat...             10
# 37421  Thank you Kane for everything you have given t...              5
#
# [37264 rows x 13 columns]

# %%
# checking newly added column
data.columns
# Out:
# Index(['video_id', 'title', 'channel_id', 'channel_title', 'published_at',
#        'view_count', 'likes', 'dislikes', 'comment_count', 'tags',
#        'description', 'comments', 'publisd_month'],
#       dtype='object')

# %% [markdown]
# **<h3>7. Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb'
# and so on.....**

# %%
data["published_month"]=data["published_at"].dt.month_name()
data
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# 0      UC6UL29enLNe4mqwTfAyeNuw             Bundesliga 2021-07-01 10:00:00
# 1      UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO 2021-06-10 16:00:00
# 2      UClBKH8yZRcM4AsRjDVEdjMg     Television Academy 2021-09-20 01:03:32
# 3      UCsmXiDP8S40uBeJYxvyulmA                    JO1 2021-03-03 10:00:17
# 4      UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering 2021-12-07 13:00:00
# ...                         ...                    ...                 ...
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q               Lil Tjay 2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                    NBA 2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA                MAMAMOO 2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g         Master Podcast 2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w      Tottenham Hotspur 2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 0         1048888    19515       226           1319
# 1        15352638   359277      7479          18729
# 2          925281    11212       401            831
# 3         2641597    39131       441           3745
# 4          715724    32887       367           1067
# ...           ...      ...       ...            ...
# 37417   120408275  2180780     35871          81360
# 37418     2841917    20759      1049           2624
# 37419    13346678   720854      4426          90616
# 37420      252057    19198      1234           1471
# 37421     2252090    34063       868           2004
#
#                                                     tags  \
# 0      football soccer ftbol alemn Bundesliga season ...
# 1      Migos Avalanche Quality Control Music/Motown R...
# 2
# 3      PRODUCE101JAPAN              JO1   TheSTAR STA...
# 4      retaining wall New Jersey highway Direct Conne...
# ...                                                  ...
# 37417  Lil Tjay Steady Calling My Phone Calling My Ph...
# 37418  NBA G League Basketball game-0022000187 Lakers...
# 37419  MAMAMOO  WAW  WAW MAMAMOO WAW Where Are We Now...
# 37420  master masterpodcast lord lord vinheteiro z z ...
# 37421  Spurs Tottenham Hotspur   Tottenham Leicester ...
#
#                                              description  \
# 0      Enjoy the best skills and goals from Jadon San...
# 1      Watch the the official video for Migos - "Aval...
# 2      Hannah Waddingham wins the Emmy for Supporting...
# 3      JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO\n\n---...
# 4      One of the most important (and innocuous) part...
# ...                                                  ...
# 37417  Official video for "Calling My Phone" by Lil T...
# 37418  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  [MV]  (MAMAMOO) - Where Are We Now\n\nInstagra...
# 37420  DOCTOR HAIR\nhttps://www.thedoctorhair.com/?fb...
# 37421  Two minute highlights from Tottenham Hotspur's...
#
#                                                 comments  publisd_month  \
# 0      Respect to Dortmund fans,must be sad losing hi...              7
# 1      Migos just makes me want to live my live to th...              6
# 2      Hannah's energy bursts through any screen. Wel...              9
# 3      youngVer><  REN is really PERFECT. It's not ju...              3
# 4       Keep up with all my projects here: https://pr...             12
# ...                                                  ...            ...
# 37417  'DESTINED 2 WIN' OUT NOW !! https://liltjay.ln...              2
# 37418  Montrezl Harrell is going crazy with the rebou...              1
# 37419  I honestly do not know why this song hit so ha...              6
# 37420  Foi um prazer passar esta tarde com vocs debat...             10
# 37421  Thank you Kane for everything you have given t...              5
#
#       published_month
# 0                July
# 1                June
# 2           September
# 3               March
# 4            December
# ...               ...
# 37417        February
# 37418         January
# 37419            June
# 37420         October
# 37421             May
#
# [37264 rows x 14 columns]

# %%
#Checking all unique values in published_month column
data["published_month"].unique()
# Out:
# array(['July', 'June', 'September', 'March', 'December', 'October',
#        'August', 'April', 'May', 'November', 'February', 'January'],
#       dtype=object)

# %% [markdown]
# **<h3>8. Find the number of videos published each month and arrange the months in a decreasing order based
# on the video count.**

# %%
#Using pivot_table() and giving different parameters I created pivot tablet taking 'published_months' as index and 'video id' as count of videos published in each month and then sorted using sort_values()
pd.pivot_table(data, index = ["published_month"], aggfunc="count", values="video_id").sort_values(by=['video_id'], ascending=False)
# Out:
#                  video_id
# published_month
# October              4976
# September            4854
# November             4821
# August               4250
# December             3063
# July                 2331
# June                 2305
# March                2248
# February             2125
# April                2119
# January              2099
# May                  2073

# %% [markdown]
#  Highest number of videos were published in October month and loweest in May month

# %% [markdown]
# **<h3>9. Find the count of unique video_id, channel_id and channel_title.**

# %%
#To find count of unique video_id, channel_id and channel_title nunique() function was called.
data[["video_id", "channel_id", "channel_title"]].nunique()
# Out:
# video_id         37264
# channel_id       10891
# channel_title    10813
# dtype: int64

# %% [markdown]
#  And from these counts we can clearly see that all video_ids are unique which is obvious, channel_id and channel_titles of more than 50% channels and videos are similar.

# %% [markdown]
# **<h3>10. Find the top 10 channel names having the highest number of videos in the dataset and the bottom 10
# having lowest number of videos.**

# %%
a=data.pivot_table(index=["channel_title"],values=["title"],aggfunc="sum").sort_values(by=["title"])

# %%
#To get top 10 channels with highest video counts we can used .head() and get as many highest count we want 
a.head(10)
# Out:
#                                                                 title
# channel_title
# Cook with sarabjit                                      | Loki recipe
# Raksha ki Rasoi                                               /peanut
#   :Diggle Classic                                  # EP.38-01 #130529
# Nisha Madhulika                -     Cornmeal Dosa & Chutney      ...
# Ms. Helen                      FIXI PRICE  21          Fix price 2...
# Marathi Kitchen                         | Cripy Dosa with Red Chutney
# The Lallantop                 ?Shoaib Akhtar| India vs Pakistan| T...
# EUGBAK                                 [Eng Sub][ ]   X     [Eng Sub]
# Ultra Bollywood               | Govinda, Karisma Kapoor, Kader Kha...
# anu swayam kalike                        |Modaka | Sihi kadubu recipe

# %%
#And using tail() we can extract bottom rows which has lowest video counts
a.tail(10)
# Out:
#                                                              title
# channel_title
# chiimelo                                www21000""!!!!wwGRWM6""!!!
#  / staRYs*                                                    wwww
# Kimagure Cook                                            wwwwwwwww
#  / Honoka                                         wwwwwwwwwwwwwwww
# yama                                                       yama MV
# RYuK FPS         yoru best clip #shorts #yoru #valorant (credit...
# Tinker Man Mick  you can pull the joystick up, but why?shoot fa...
# ami                                                         z900rs
# AzadliqRadiosu   zl grntlr: Azrbaycan sgrlri dedilr ki, bu df h...
# NTV                    zmir'de yaanan depremde kedinin panik anlar

# %% [markdown]
# **<h3>11. Find the title of the video which has the maximum number of likes and the title of the video having
# minimum likes and write your inferences.**

# %%
maxlike = pd.pivot_table(data, index = ["title"], values =["likes"]).sort_values(by=["likes"], ascending=False)
minlike = pd.pivot_table(data, index = ["title"], values =["likes"]).sort_values(by=["likes"], ascending=False)

# %%
maxlike.head(1)
# Out:
#                                     likes
# title
# BTS () 'Dynamite' Official MV  31837675.0

# %% [markdown]
# Maximum number of likes are on "BTS () 'Dynamite' Official MV" video which is around 31 million

# %%
minlike.tail(1)
# Out:
#                                likes
# title
# Leading the Charge | Circle K   22.0

# %% [markdown]
#  Minimum number of likes are on "Leading the Charge | Circle K" video which is only 22

# %% [markdown]
# **<h3>12. Find the title of the video which has the maximum number of dislikes and the title of the video having
# minimum dislikes and write your inferences.**

# %%
maxdislike = pd.pivot_table(data, index = ["title"], values =["dislikes"]).sort_values(by=["dislikes"], ascending=False)
mindislike = pd.pivot_table(data, index = ["title"], values =["dislikes"]).sort_values(by=["dislikes"], ascending=False)

# %%
maxdislike.head(1)
# Out:
#                                       dislikes
# title
# Cuties | Official Trailer | Netflix  2397733.0

# %% [markdown]
# Maximum number of dislikes are on "Cuties | Official Trailer | Netflix" video which is around 2 million

# %%
mindislike.tail(1)
# Out:
#                                         dislikes
# title
# Tims For Good: A Taste Of The Familiar       3.0

# %% [markdown]
#  Minimum number of dislikes are on "Tims For Good: A Taste Of The Familiar" video which is only 3

# %% [markdown]
# **<h3>13. Does the number of views have any effect on how many people disliked the video? Support your
# answer with a metric and a plot.**

# %%
#Creating correlation matrix to find out corrlation between view_count and dislikes using .corr()
data[["view_count","dislikes"]].corr()
# Out:
#             view_count  dislikes
# view_count    1.000000  0.684576
# dislikes      0.684576  1.000000

# %%
import seaborn as sns
sns.scatterplot(x="view_count",y="dislikes",data= data)
# Out:
# <Axes: xlabel='view_count', ylabel='dislikes'>

# %%
data["view_count"].corr(df["dislikes"])

# %% [markdown]
# From the correlation matrix we can see that there is positive correlation of .68 between views and dislikes. Also from scatter plot trendline we can clearly see a positive correlation between these two variables. Although the relation is positive but the correlation is not high its low. We can say that there is effect of number of views on dislikes but not too much.

# %% [markdown]
# **<h3>14. Display all the information about the videos that were published in January, and mention the count of
# videos that were published in January.**

# %%
#With this condition we can see all the information of videos that were published in January month
data[data["published_month"]=="Jan"]

# %%
#Count of videos that were published in January using == condition filter and . count() to count

#jan_video_count = data[data["published_month"]=="Jan"]
#jan_video_count["video_id"].count()

data[data["published_month"]=="Jan"]["video_id"].count()

# %% [markdown]
# In January 2099 videos were published.

# %% [markdown]
# # <center>End of Project
